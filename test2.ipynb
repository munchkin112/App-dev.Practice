# %%
import requests

call_url = "https://api.open-meteo.com/v1/forecast?latitude=37.5663&longitude=127.0236&current=temperature_2m,relative_humidity_2m,weather_code,wind_speed_10m&timezone=auto"

response = requests.get(call_url, timeout=4.0)

print("상태 코드:", response.status_code)

data = response.json()

print("전체 응답:", data)
print("현재 날씨:", data["current"])
print("현재 기온:", data["current"]["temperature_2m"])
# Out:
# 상태 코드: 200
# 전체 응답: {'latitude': 37.55, 'longitude': 127.0, 'generationtime_ms': 0.11098384857177734, 'utc_offset_seconds': 32400, 'timezone': 'Asia/Seoul', 'timezone_abbreviation': 'GMT+9', 'elevation': 26.0, 'current_units': {'time': 'iso8601', 'interval': 'seconds', 'temperature_2m': '°C', 'relative_humidity_2m': '%', 'weather_code': 'wmo code', 'wind_speed_10m': 'km/h'}, 'current': {'time': '2026-08-14T12:15', 'interval': 900, 'temperature_2m': 25.9, 'relative_humidity_2m': 77, 'weather_code': 2, 'wind_speed_10m': 4.6}}
# 현재 날씨: {'time': '2026-08-14T12:15', 'interval': 900, 'temperature_2m': 25.9, 'relative_humidity_2m': 77, 'weather_code': 2, 'wind_speed_10m': 4.6}
# 현재 기온: 25.9

# %%
import requests
print("requests 불러오기 성공")

# %%
import requests
response = requests.get(call_url, timeout= 5)

response.json()
# Out:
# {'latitude': 37.55,
#  'longitude': 127.0,
#  'generationtime_ms': 0.09775161743164062,
#  'utc_offset_seconds': 32400,
#  'timezone': 'Asia/Seoul',
#  'timezone_abbreviation': 'GMT+9',
#  'elevation': 26.0,
#  'current_units': {'time': 'iso8601',
#   'interval': 'seconds',
#   'temperature_2m': '°C',
#   'relative_humidity_2m': '%',
#   'weather_code': 'wmo code',
#   'wind_speed_10m': 'km/h'},
#  'current': {'time': '2026-08-14T12:15',
#   'interval': 900,
#   'temperature_2m': 25.9,
#   'relative_humidity_2m': 77,
#   'weather_code': 2,
#   'wind_speed_10m': 4.6}}

# %%
only_url = "https://api.open-meteo.com/v1/forecast?latitude=37.5663&longitude=127.0236&current=temperature_2m,relative_humidity_2m,weather_code,wind_speed_10m&timezone=auto"
params_value = {
    "latitude" : 36.8,

}

# %%
import httpx

only_url = "https://api.open-meteo.com/v1/forecast"

params_value = {
    "latitude": 37.5663,
    "longitude": 127.0236,
    "current": "temperature_2m,relative_humidity_2m,weather_code,wind_speed_10m",
    "timezone": "auto"
}


async def get_weather():

    async with httpx.AsyncClient(timeout=3) as client:
        response = await client.get(
            only_url,
            params=params_value
        )

    data = response.json()

    return data

# %%
result = await get_weather()
print(result)
# Out:
# {'latitude': 37.55, 'longitude': 127.0, 'generationtime_ms': 0.08797645568847656, 'utc_offset_seconds': 32400, 'timezone': 'Asia/Seoul', 'timezone_abbreviation': 'GMT+9', 'elevation': 26.0, 'current_units': {'time': 'iso8601', 'interval': 'seconds', 'temperature_2m': '°C', 'relative_humidity_2m': '%', 'weather_code': 'wmo code', 'wind_speed_10m': 'km/h'}, 'current': {'time': '2026-08-14T12:30', 'interval': 900, 'temperature_2m': 26.0, 'relative_humidity_2m': 76, 'weather_code': 2, 'wind_speed_10m': 4.6}}
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_1316\2794117408.py:1: RuntimeWarning: coroutine 'get_weather' was never awaited
#   result = await get_weather()
# ...

# %%
only_url,
params_value
# Out:
# {'latitude': 36.8}

# %%
print(api_key is not None)
# Out:
# False

# %%
import os
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("GOOGLE_API_KEY")

print("값 존재 여부:", api_key is not None)
print("타입:", type(api_key))
# Out:
# 값 존재 여부: False
# 타입: <class 'NoneType'>
